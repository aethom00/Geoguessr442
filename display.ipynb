# %%
from Agent import Agent

# %%
agent = Agent()
agent.init()

# %%
agent.generate_images(1_000,limit=1)
# Out:
# Iteration 1: Finding images...
# Generated 1 Image(s)
# Iteration 2: Finding images...
# Generated 1 Image(s)
# Iteration 3: Finding images...
# Generated 1 Image(s)
# Iteration 4: Finding images...
# Generated 1 Image(s)
# Iteration 5: Finding images...
# Generated 1 Image(s)
# Iteration 6: Finding images...
# Generated 1 Image(s)
# Iteration 7: Finding images...
# Generated 1 Image(s)
# Iteration 8: Finding images...
# Could not find any images in the bounding box: -74.0,31.8,-70.0,34.4. Trying again...
# Finding images...
# Generated 1 Image(s)
# Iteration 9: Finding images...
# Generated 1 Image(s)
# Iteration 10: Finding images...
# Generated 1 Image(s)
# Iteration 11: Finding images...
# Generated 1 Image(s)
# Iteration 12: Finding images...
# Generated 1 Image(s)
# Iteration 13: Finding images...
# Generated 1 Image(s)
# Iteration 14: Finding images...
# Generated 1 Image(s)
# Iteration 15: Finding images...
# Generated 1 Image(s)
# Iteration 16: Finding images...
# ...

# %%
agent.show()
