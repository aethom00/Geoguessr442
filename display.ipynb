# %%
from Agent import Agent

# %%
agent = Agent()
agent.init(model_path='vision_model_v1.keras')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Loading existing model...

# %%
# Raw Score
agent.evaluate_model(images_to_test=100, show=False)
# Out:
# Generating images to test...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/davidpidugu/ML/GeoGuessr/display.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/davidpidugu/ML/GeoGuessr/display.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Raw Score
# ----> <a href='vscode-notebook-cell:/Users/davidpidugu/ML/GeoGuessr/display.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> agent.evaluate_model(images_to_test=100, show=False)
#
# File ~/ML/GeoGuessr/Agent.py:86, in Agent.evaluate_model(self, images_to_test, use_noisy_images, show)
#      84 def evaluate_model(self, images_to_test=10, use_noisy_images=False, show=True):
#      85     print("Generating images to test...")
# ---> 86     self.refresh(images_to_test, verbose=False)
#      87     print("Done generating images to test")
#      89     # Prepare the dataset
#
# ...

# %%
# See the model in action
agent.evaluate_model(images_to_test=10, show=True)
# Out:
# Generating images to test...
# Done generating images to test
# 1/1 [==============================] - 0s 92ms/step - loss: 7.7761 - accuracy: 0.2857
# Loss: 7.776112079620361, Accuracy: 0.2857142984867096
# ...
# 1/1 [==============================] - 0s 10ms/step

# %%
agent.predict_images_in_folder(folder_path='Images', show=True)
# Out:
# 1/1 [==============================] - 0s 36ms/step
