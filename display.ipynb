# %%
from gui import GUI
from city_image import get_images

# %%
g = GUI(15, 10)
g.init()

# %%
g.generate_random_output()
g.show()

# %%
dots = [
    (-83.0458, 42.3314),  # Detroit
    (-74.0060, 40.7128),  # New York City
    (-80.1918, 25.7617),  # Miami
    (-122.4194, 37.7749)  # San Francisco
]
g.clear_output()
#g.toggle_ticks(show_ticks=False)
g.show(dots=dots, color='blue')

# %%
imgs = get_images(1)
imgs[0].show(noisy=False)
imgs[0].show(noisy=True)

# %%
from generate_images import generate_image
# Out:
# Saved image to Data\47.4, -114.0.jpg
# Image found and saved for bbox: -114.0,44.8,-110.0,47.4
