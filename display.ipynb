# %%
from Agent import Agent

# %%
agent = Agent()
agent.init()

# %%
agent.generate_images(10,limit=1)
# Out:
# Iteration 1: Finding images...
# Generated 1 Image(s)
# Iteration 2: Finding images...
# Generated 1 Image(s)
# Iteration 3: Finding images...
# Generated 1 Image(s)
# Iteration 4: Finding images...
# Generated 1 Image(s)
# Iteration 5: Finding images...
# Could not find any images in the bounding box: -126.0,29.2,-122.0,31.8. Trying again...
# Finding images...
# Could not find any images in the bounding box: -122.0,29.2,-118.0,31.8. Trying again...
# Finding images...
# Generated 1 Image(s)
# Iteration 6: Finding images...
# Generated 1 Image(s)
# Iteration 7: Finding images...
# Generated 1 Image(s)
# Iteration 8: Finding images...
# Generated 1 Image(s)
# Iteration 9: Finding images...
# Generated 1 Image(s)
# Iteration 10: Finding images...
# Generated 1 Image(s)

# %%
agent.show()
