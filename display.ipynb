# %%
from Agent import Agent

# %%
agent = Agent()
agent.init()

# %%
agent.generate_images(10,limit=1)
# Out:
# Iteration 1: Finding new image
# Image Generated
#
# Iteration 2: Finding new image
# Image Generated
#
# Iteration 3: Finding new image
# Image Generated
#
# Iteration 4: Finding new image
# Image Generated
#
# Iteration 5: Finding new image
# Image Generated
#
# Iteration 6: Finding new image
# Image Generated
#
# Iteration 7: Finding new image
# Image Generated
#
# Iteration 8: Finding new image
# Image Generated
#
# Iteration 9: Finding new image
# Couldn't find any images in the bounding box: [(-70.0, 34.4), (-66.0, 37.0)]. Trying again...
# Finding new image
# Image Generated
#
# Iteration 10: Finding new image
# Image Generated
#
# Done generating images, please view diagram

# %%
for city_img in agent.city_images:
    agent.gui.output[city_img.grid_y][city_img.grid_x] = 1
agent.show()
